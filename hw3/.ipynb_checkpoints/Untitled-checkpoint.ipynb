# %%
load("217548/HW3.sage")
# Out:
# Begin
# 0
# found
# 84
# 5
# 1
# found
# 111
# 5
# 2
# found
# 32
# 3
# 3
# found
# 98
# 3
# 4
# found
# 117
# 2
# 5
# found
# 114
# -3
# 6
# found
# 110
# -3
# 7
# found
# 44
# 2
# 8
# found
# 32
# -9
# 9
# found
# 111
# 2
# 10
# found
# 114
# 2
# 11
# found
# 32
# 1
# 12
# found
# 110
# -10
# 13
# found
# 111
# 6
# 14
# found
# 116
# -1
# 15
# found
# 32
# 4
# 16
# found
# 116
# -2
# 17
# found
# 111
# 3
# 18
# found
# 32
# 4
# 19
# found
# 98
# -3
# 20
# found
# 117
# 5
# 21
# found
# 114
# -9
# 22
# found
# 110
# 0
# 23
# found
# 44
# -5
# 24
# found
# 32
# -2
# 25
# found
# 116
# -3
# 26
# found
# 104
# -1
# 27
# found
# 97
# -9
# 28
# found
# 116
# 10
# 29
# found
# 32
# 4
# 30
# found
# 105
# -2
# 31
# found
# 115
# 5
# 32
# found
# 32
# -2
# 33
# found
# 116
# -5
# 34
# found
# 104
# -1
# 35
# found
# 101
# -3
# 36
# found
# 32
# 5
# 37
# found
# 113
# 6
# 38
# found
# 117
# 2
# 39
# found
# 101
# -3
# 40
# found
# 115
# -3
# 41
# found
# 116
# 4
# 42
# found
# 105
# -1
# 43
# ...

# %%
load("217548/HW3.sage")
# Out:
# Found : "To burn, or not to burn, that is the question: The optimal strategy is to choose randomly!"

# %%
load("217548/HW3.sage")
# Out:
# Found : "There is a good duplicity in this world, and it is worth fighting for."
# failed once
# failed once
# failed once

# %%
load("217548/HW3.sage")
# Out:
# Found : "Star Wars The Last Jedi on 03.01.2018 @ 17:40. I wonder who Supreme Leader Snoke is@_@"

# %%
load("217548/HW3.sage")
# Out:
# Found : "I told you 11 times, flasher is not a good password! Do I need to repeat it 9 more times?"

# %%
load("217548/HW3.sage")
# Out:
# Found : " 487276508993871451157203988 "
